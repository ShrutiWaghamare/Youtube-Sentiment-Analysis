# %% [markdown]
# # How many max features?

# %%
# !pip install mlflow boto3 awscli
# Out:
# Requirement already satisfied: mlflow in C:\Users\shrut\miniconda3\Lib\site-packages (2.19.0)
# Requirement already satisfied: boto3 in C:\Users\shrut\miniconda3\Lib\site-packages (1.42.63)
# Requirement already satisfied: awscli in C:\Users\shrut\miniconda3\Lib\site-packages (1.44.53)
# Requirement already satisfied: mlflow-skinny==2.19.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (2.19.0)
# Requirement already satisfied: Flask<4 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (3.1.3)
# Requirement already satisfied: Jinja2<4,>=3.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (3.1.6)
# Requirement already satisfied: alembic!=1.10.0,<2 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (1.18.4)
# Requirement already satisfied: docker<8,>=4.0.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (3.10.2)
# Requirement already satisfied: matplotlib<4 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (3.10.3)
# Requirement already satisfied: numpy<3 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (2.3.5)
# Requirement already satisfied: pandas<3 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (2.3.0)
# Requirement already satisfied: pyarrow<19,>=4.0.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (18.1.0)
# Requirement already satisfied: scikit-learn<2 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (1.5.2)
# Requirement already satisfied: scipy<2 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (1.17.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (2.0.46)
# Requirement already satisfied: waitress<4 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (0.96.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (3.1.46)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (1.39.1)
# Requirement already satisfied: packaging<25 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (24.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (5.29.6)
# Requirement already satisfied: pyyaml<7,>=5.1 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (0.5.5)
# Requirement already satisfied: Mako in C:\Users\shrut\miniconda3\Lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in C:\Users\shrut\miniconda3\Lib\site-packages (from alembic!=1.10.0,<2->mlflow) (4.15.0)
# Requirement already satisfied: colorama in C:\Users\shrut\miniconda3\Lib\site-packages (from click<9,>=7.0->mlflow-skinny==2.19.0->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow) (2.47.0)
# Requirement already satisfied: pywin32>=304 in C:\Users\shrut\miniconda3\Lib\site-packages (from docker<8,>=4.0.0->mlflow) (311)
# Requirement already satisfied: urllib3>=1.26.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.6.1)
# Requirement already satisfied: blinker>=1.9.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in C:\Users\shrut\miniconda3\Lib\site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\shrut\miniconda3\Lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.19.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\shrut\miniconda3\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.19.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\shrut\miniconda3\Lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in C:\Users\shrut\miniconda3\Lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow) (4.7.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in C:\Users\shrut\miniconda3\Lib\site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in C:\Users\shrut\miniconda3\Lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in C:\Users\shrut\miniconda3\Lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.19.0->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\shrut\miniconda3\Lib\site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\shrut\miniconda3\Lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from matplotlib<4->mlflow) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\shrut\miniconda3\Lib\site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in C:\Users\shrut\miniconda3\Lib\site-packages (from matplotlib<4->mlflow) (12.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\shrut\miniconda3\Lib\site-packages (from matplotlib<4->mlflow) (3.3.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in C:\Users\shrut\miniconda3\Lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.19.0->mlflow) (0.60b1)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\shrut\miniconda3\Lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\shrut\miniconda3\Lib\site-packages (from pandas<3->mlflow) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\shrut\miniconda3\Lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\shrut\miniconda3\Lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.19.0->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\shrut\miniconda3\Lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.19.0->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\shrut\miniconda3\Lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.19.0->mlflow) (2026.2.25)
# Requirement already satisfied: pyasn1>=0.1.3 in C:\Users\shrut\miniconda3\Lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow) (0.6.2)
# Requirement already satisfied: joblib>=1.2.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from scikit-learn<2->mlflow) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\shrut\miniconda3\Lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.3.0)
# Requirement already satisfied: botocore<1.43.0,>=1.42.63 in C:\Users\shrut\miniconda3\Lib\site-packages (from boto3) (1.42.63)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in C:\Users\shrut\miniconda3\Lib\site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in C:\Users\shrut\miniconda3\Lib\site-packages (from boto3) (0.16.0)
# Requirement already satisfied: docutils<=0.19,>=0.18.1 in C:\Users\shrut\miniconda3\Lib\site-packages (from awscli) (0.19)

# %%
import mlflow
# Step 2: Set up the MLflow tracking server
mlflow.set_tracking_uri("http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/")

# %%
# Set or create an experiment
mlflow.set_experiment("Exp 3 - TfIdf Trigram max_features")
# Out:
# 2026/03/10 14:38:15 INFO mlflow.tracking.fluent: Experiment with name 'Exp 3 - TfIdf Trigram max_features' does not exist. Creating a new experiment.
# <Experiment: artifact_location='s3://ytmlflow-bucket-2026/3', creation_time=1773133694903, experiment_id='3', last_update_time=1773133694903, lifecycle_stage='active', name='Exp 3 - TfIdf Trigram max_features', tags={}>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import mlflow
import mlflow.sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# %%
df = pd.read_csv('reddit_preprocessing.csv').dropna(subset=['clean_comment'])
df.shape
# Out:
# (36662, 2)

# %%
# Step 1: Function to run the experiment
def run_experiment_tfidf_max_features(max_features):
    ngram_range = (1, 3)  # Trigram setting

    # Step 2: Vectorization using TF-IDF with varying max_features
    vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=max_features)

    X_train, X_test, y_train, y_test = train_test_split(df['clean_comment'], df['category'], test_size=0.2, random_state=42, stratify=df['category'])

    X_train = vectorizer.fit_transform(X_train)
    X_test = vectorizer.transform(X_test)

    # Step 4: Define and train a Random Forest model
    with mlflow.start_run() as run:
        # Set tags for the experiment and run
        mlflow.set_tag("mlflow.runName", f"TFIDF_Trigrams_max_features_{max_features}")
        mlflow.set_tag("experiment_type", "feature_engineering")
        mlflow.set_tag("model_type", "RandomForestClassifier")

        # Add a description
        mlflow.set_tag("description", f"RandomForest with TF-IDF Trigrams, max_features={max_features}")

        # Log vectorizer parameters
        mlflow.log_param("vectorizer_type", "TF-IDF")
        mlflow.log_param("ngram_range", ngram_range)
        mlflow.log_param("vectorizer_max_features", max_features)

        # Log Random Forest parameters
        n_estimators = 200
        max_depth = 15

        mlflow.log_param("n_estimators", n_estimators)
        mlflow.log_param("max_depth", max_depth)

        # Initialize and train the model
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=42)
        model.fit(X_train, y_train)

        # Step 5: Make predictions and log metrics
        y_pred = model.predict(X_test)

        # Log accuracy
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        # Log classification report
        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Log confusion matrix
        conf_matrix = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title(f"Confusion Matrix: TF-IDF Trigrams, max_features={max_features}")
        plt.savefig("confusion_matrix.png")
        mlflow.log_artifact("confusion_matrix.png")
        plt.close()

        # Log the model
        mlflow.sklearn.log_model(model, f"random_forest_model_tfidf_trigrams_{max_features}")

# Step 6: Test various max_features values
max_features_values = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]

for max_features in max_features_values:
    run_experiment_tfidf_max_features(max_features)
# Out:
# 2026/03/10 14:40:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run TFIDF_Trigrams_max_features_1000 at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3/runs/98688777725141c49dc2e6c92730448d
# 🧪 View experiment at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3
# 2026/03/10 14:41:56 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run TFIDF_Trigrams_max_features_2000 at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3/runs/7e537d697cb9423586d88f31a0fe0691
# 🧪 View experiment at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3
# 2026/03/10 14:45:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run TFIDF_Trigrams_max_features_3000 at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3/runs/eec5a25cdcc74234a425ebd96130057c
# 🧪 View experiment at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3
# 2026/03/10 14:48:47 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run TFIDF_Trigrams_max_features_4000 at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3/runs/53e1ad1fae26452cb3fa78ce8433a1ef
# 🧪 View experiment at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3
# 2026/03/10 14:51:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run TFIDF_Trigrams_max_features_5000 at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3/runs/1ba1abd19e76413da47f774e3ceb21e4
# 🧪 View experiment at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3
# 2026/03/10 14:55:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run TFIDF_Trigrams_max_features_6000 at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3/runs/8b69767e93fa469b9a61ddaaf328da91
# 🧪 View experiment at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3
# 2026/03/10 14:56:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run TFIDF_Trigrams_max_features_7000 at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3/runs/918201ad962b47e1ac99f35892ca87eb
# 🧪 View experiment at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3
# 2026/03/10 14:57:37 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run TFIDF_Trigrams_max_features_8000 at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3/runs/d6e877121c124dcbb3c752002730439e
# 🧪 View experiment at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3
# 2026/03/10 14:58:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run TFIDF_Trigrams_max_features_9000 at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3/runs/46d6ab90810d42ef9c9b12eafc87e437
# 🧪 View experiment at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3
# 2026/03/10 15:00:11 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run TFIDF_Trigrams_max_features_10000 at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3/runs/9ceaaa248aed4f2785ab1fe3df686bc5
# 🧪 View experiment at: http://ec2-18-233-223-218.compute-1.amazonaws.com:5000/#/experiments/3
